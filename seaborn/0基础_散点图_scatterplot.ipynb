# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = pd.read_csv("seaborn-data/diamonds.csv")
display(diamonds.head(5))

# Draw a scatter plot while assigning point colors and sizes to different variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))

# 移除左侧和底部的坐标轴边框（更简洁的视觉风格）
sns.despine(f, left=True, bottom=True)

# 指定 clarity（钻石净度等级）的显示顺序，从最低净度 I1 到最高净度 IF。
# 确保图例中的颜色按此顺序排列（而非默认字母顺序）。
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.scatterplot(
    x="carat", y="price",           # x轴=克拉数，y轴=价格
    hue="clarity", size="depth",    # 颜色=净度，点大小=深度
    palette="ch:r=-.2,d=.3_r",      # 自定义颜色映射
    hue_order=clarity_ranking,      # 按定义的顺序显示颜色
    sizes=(1, 8), linewidth=0,      # 点大小范围1-8，无描边
    data=diamonds, ax=ax            # 数据源和绘图坐标轴
)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# <Axes: xlabel='carat', ylabel='price'>
