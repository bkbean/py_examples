# %%
from ex_concurrent import proc_map_task,proc_submit_task,thre_map_task,thre_submit_task

# %%
# %timeit proc_map_task(10,1)
# %timeit proc_submit_task(10,1)
# %timeit proc_map_task(10,2)
# %timeit proc_submit_task(10,2)
# %timeit proc_map_task(10,4)
# %timeit proc_submit_task(10,4)
# %timeit proc_map_task(10,8)
# %timeit proc_submit_task(10,8)
# Out:
# 9.27 s ± 11.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 9.29 s ± 7.82 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.28 s ± 8.12 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.27 s ± 11.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3.27 s ± 9.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3.28 s ± 11.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.3 s ± 15 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.31 s ± 8.81 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit thre_map_task(10,1)
# %timeit thre_submit_task(10,1)
# %timeit thre_map_task(10,2)
# %timeit thre_submit_task(10,2)
# %timeit thre_map_task(10,4)
# %timeit thre_submit_task(10,4)
# %timeit thre_map_task(10,8)
# %timeit thre_submit_task(10,8)
# Out:
# 9.01 s ± 886 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 9.01 s ± 745 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.01 s ± 367 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 5.01 s ± 530 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3 s ± 351 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 3 s ± 537 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2 s ± 395 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2 s ± 361 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
